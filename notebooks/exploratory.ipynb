# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import sys
sys.path.append('../src')
from preprocess import clean_lyrics

# %%
# Load sample data
df = pd.read_csv(r'C:\Backup\Northeastern\Studies\Summer Sem\NLP\5million\data\labeled_emotions.csv')

# %%
# Basic info
print(df.head())
print(df['labels'].value_counts())
# Out:
#                                               lyrics labels
# 0  [Chorus: Opera Steve & Cam'ron]\nKilla Cam, Ki...  anger
# 1  [Produced by Irv Gotti]\n\n[Intro]\nYeah, hah,...  anger
# 2  Maybe cause I'm eatin\nAnd these bastards fien...  anger
# 3  [Produced by Kanye West and Brian Miller]\n\n[...  anger
# 4  [Intro]\nSo they ask me\n"Young boy\nWhat you ...  anger
# labels
# anger       7684
# fear         958
# disgust      625
# sadness      340
# surprise     257
# joy          136
# Name: count, dtype: int64

# %%
# Length distribution
df['length'] = df['lyrics'].apply(lambda x: len(str(x).split()))
sns.histplot(df['length'], bins=50)
plt.show()
